# %%
from numpy import load

if __name__ == '__main__':
    distance = load('muestra.npy')
    print(distance.shape)
    x, y, z = [], [], []
    for d in distance:
        x.append(d[0])
        y.append(d[1])
        z.append(d[2])
# Out:
# (17361, 3)

# %%
from matplotlib import pyplot as plt


plt.plot(y)
plt.title('Hist de la distancia (t5 - t6) * 8')
plt.show()
print(min(distance))
max(distance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-3d52f908bbcd> in <module>
#       5 plt.title('Hist de la distancia (t5 - t6) * 8')
#       6 plt.show()
# ----> 7 print(min(distance))
#       8 max(distance)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.hist(y)
plt.show()
